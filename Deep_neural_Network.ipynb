# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)

# %%
n_pts = 500
X, y = datasets.make_circles(n_samples= n_pts, random_state= 123, noise= 0.1, factor= 0.2)

# %%
plt.scatter(X[y== 0, 0], X[y== 0, 1])
plt.scatter(X[y== 1, 0], X[y== 1, 1])

# %%
model = Sequential()
model.add(Dense(4, input_shape= (2,), activation= 'sigmoid'))
model.add(Dense(1, activation= 'sigmoid'))
model.compile(Adam(lr= 0.01), 'binary_crossentropy', metrics= ['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
h = model.fit(x= X, y= y, verbose= 1, batch_size= 20, epochs= 100, shuffle='true')
# Out:
# Epoch 1/100
# 25/25 [==============================] - 5s 3ms/step - loss: 0.7203 - accuracy: 0.5000
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6956 - accuracy: 0.4540
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5180
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.4980
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.5000
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.5580
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.6220
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.4660
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.4800
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.6380
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6799 - accuracy: 0.6880
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6725 - accuracy: 0.6960
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6641 - accuracy: 0.8240
# Epoch 14/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6497 - accuracy: 0.6820
# Epoch 15/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.8320
# Epoch 16/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6149 - accuracy: 0.8660
# Epoch 17/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5957 - accuracy: 0.8660
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5736 - accuracy: 0.8720
# Epoch 19/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5525 - accuracy: 0.8740
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.8660
# Epoch 21/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5107 - accuracy: 0.8680
# Epoch 22/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4911 - accuracy: 0.8680
# Epoch 23/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4703 - accuracy: 0.8680
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4515 - accuracy: 0.8740
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.8740
# Epoch 26/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8820
# Epoch 27/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3851 - accuracy: 0.8900
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.8900
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.9100
# Epoch 30/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3126 - accuracy: 0.9180
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2907 - accuracy: 0.9400
# Epoch 32/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2696 - accuracy: 0.9400
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9580
# Epoch 34/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2335 - accuracy: 0.9660
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2171 - accuracy: 0.9740
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2024 - accuracy: 0.9860
# Epoch 37/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9940
# Epoch 38/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9960
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1658 - accuracy: 0.9980
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1553 - accuracy: 0.9980
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1458 - accuracy: 0.9980
# Epoch 42/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1373 - accuracy: 0.9980
# Epoch 43/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1296 - accuracy: 0.9980
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9980
# Epoch 45/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1157 - accuracy: 0.9980
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1097 - accuracy: 0.9980
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.9980
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 1.0000
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 1.0000
# Epoch 50/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0901 - accuracy: 1.0000
# Epoch 51/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0859 - accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 1.0000
# Epoch 53/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0755 - accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0697 - accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0670 - accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 70/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 81/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 82/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 86/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 87/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 88/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 89/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 90/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000

# %%
plt.plot(h.history['accuracy'])
plt.xlabel('epoch')
plt.legend(['accuracy'])
plt.title('accuracy')
# Out:
# Text(0.5, 1.0, 'accuracy')

# %%
plt.plot(h.history['loss'])
plt.xlabel('epoch')
plt.legend(['loss'])
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
def plot_decision_boundry(X, y, model):
  x_span = np.linspace(min(X[:, 0]) - 0.25, max(X[:, 0]) + 0.25, 50)
  y_span = np.linspace(min(X[:, 1]) - 0.25, max(X[:, 1]) + 0.25, 50)
  xx, yy = np.meshgrid(x_span, y_span)
  xx_, yy_ = xx.ravel(), yy.ravel()
  grid = np.c_[xx_, yy_]
  pred_func = model.predict(grid)
  z = pred_func.reshape(xx.shape)
  plt.contourf(xx, yy, z)

# %%
plot_decision_boundry(X, y, model)

plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])
# Out:
# 79/79 [==============================] - 0s 1ms/step

# %%
plot_decision_boundry(X, y, model)

plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

x = 0.1
y = 0.75
point = np.array([[x, y]])
prediction = model.predict(point)
plt.plot([x], [y], marker= 'o', markersize= 10, color= "red")
print("Prediction is : ", prediction)
# Out:
# 79/79 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# Prediction is :  [[0.04639725]]

# %%
plot_decision_boundry(X, y, model)

plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

x = 0.1
y = 0
point = np.array([[x, y]])
prediction = model.predict(point)
plt.plot([x], [y], marker= 'o', markersize= 10, color= "red")
print("Prediction is : ", prediction)
# Out:
# 79/79 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 29ms/step
# Prediction is :  [[0.9884901]]
